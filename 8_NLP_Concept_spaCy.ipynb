# %% [markdown]
# # José Luis Padilla Valenzuela
# ## NLP
#
# ### ***spaCy***
# Es una librería de código abierto en python para el Procesamiento del Lenguaje natural que posee modelos entrenados para varios idiomas, entre ellos el Español.
#
#
# * Es una librería pensada para funcionar en entornos productivos y es una librería con mejor rendimiento que **NLTK**.
#
#
# * Dispone de una web y de una documentación muy buena, incluso se pueden ejecutar ciertos ejemplos en la propia web: https://spacy.io/
#
#
# * Dispone también de un curso online (https://course.spacy.io/) bastante interesante.
#
#
# * Entre otras cosas con ***spaCy*** podemos hacer:
#     1. Tokenización
#     2. Lematización
#     3. Detección de Stop Words
#     4. Part of Speech (PoS)
#     5. Named Entity Recognition (NER)
#
#
# * ***spaCy*** puede ser instalado tanto con "pip" como con "conda" de la siguiente manera respectivamente:
#
# ```
# >> conda install -c conda-forge spacy
# ```
#
# * Como se ha comentado anteriormente la ventaja que tiene ***spaCy*** frente a ***NLTK*** en lo que a idiomas se refiere es que permite trabajar con varior idiomas gracias a los modelos que tiene entrenados.
#
#
# * En particular para el Español ***spaCy*** tiene entrenados dos modelos (con Redes Neuronales Convolucionales según su documentación) de pequeño y mediano tamaño con los corpus de **AnCora** (http://clic.ub.edu/corpus/es/ancora) y **WikiNER**.
#
#
# * Estos dos modelos de pequeño y mediano tamaño los podemos encontrar en la web de ***spaCy*** (https://spacy.io/models/es) y son los siguiente:
#     - es_core_news_md (93 MiB)
#     - es_core_news_sm (35 MiB)
#
#
# * ***spaCy*** hace uso de estos modelos y tienen que ser descargados, para ello debemos de abrir un terminal en python y ejecutar lo siguiente para descargar el modelo en Español (*NOTA: los que uséis conda, tener activado el entorno*).
#
#
# ```
# >> conda install -c conda-forge spacy-model-es_core_news_sm
#
# >> conda install -c conda-forge/label/cf202003 spacy-model-es_core_news_sm   para un python antiguo
# ```
#
#
# <img src="./imgs/005_spacy_es_download.png" style="width: 500px;"/>
#
#
# <hr>
#
#
# # spaCy - Arquitectura:
#
# * ***spaCy*** utiliza dos tipos de estructuras (objetos) llamados **Doc** y **Vocab**:
# <span></span><br><br>
#     - ***Doc***: Este objeto esta formado por una secuencia de Tokens (objetos de la clase ***Token***).
# <span></span><br><br>
#     - ***Vocab***: Este objeto posee un conjunto de Look-up tables (tablas de consulta) que hacen que la información común esté disponible en todos los documentos (Lemas, Stop Words, PoS, etc.).
#
# <img src="./imgs/006_spacy_architecture.png" style="width: 600px;"/>
#
#
# * Una forma sencilla de trabajar con ***spaCy*** es:
#     1. Cargar un modelo de lenguaje (por ejemplo el Español)
#     2. Dado un texto plano, crear un objeto de la clase "Doc" y pasarle el texto plano. El texto ya quedará tokenizado dentro del objeto "Doc".
#     3. Trabajar sobre las palabras del documento.
#
# <hr>
#
#
#
# # Ejemplos con spaCy

# %% [markdown]
# ## -Tokenización
#
#
# * Divide las cadenas de texto del documento en piezas más pequeñas o tokens.
#
#
# * Pasos:
#     1. Importar la librería.
#     2. Cargar un modelo de lenguaje (el Español).
#     3. Crear un documento (de la clase "Doc") pasándole un texto plano.
#     4. El objeto de la clase "Doc" ya esta tokenizado por palabras y podemos iterar sobre él.

# %%
import spacy
nlp = spacy.load('es_core_news_sm')
doc = nlp("Un radar multa a Mariano Rajoy por caminar demasiado rápido y después el juez lo libera por ser nombrado nueve meses antes por el PP y ahora pertenece a otro partido de derechas")
print('Tipo de dato: ' + str(type(doc)))
print([w.text for w in doc])
# Out:
# Tipo de dato: <class 'spacy.tokens.doc.Doc'>
# ['Un', 'radar', 'multa', 'a', 'Mariano', 'Rajoy', 'por', 'caminar', 'demasiado', 'rápido', 'y', 'después', 'el', 'juez', 'lo', 'libera', 'por', 'ser', 'nombrado', 'nueve', 'meses', 'antes', 'por', 'el', 'PP', 'y', 'ahora', 'pertenece', 'a', 'otro', 'partido', 'de', 'derechas']

# %% [markdown]
# ## -Segmentación
#
#
# * La ***segmentación*** divide las cadenas de texto en frases o párrafos.
#
#
# * Para la segmentación en spaCy hay que usar un componente llamado "**sentencizer**" que divide los textos por simbolos como puntos, interrogantes, etc.

# %%
sentencizer = nlp.create_pipe('sentencizer')
nlp.add_pipe('sentencizer')
doc = nlp('Frase numero 1. Frase número 2. Frase 3.')
print([s.text for s in doc.sents])
# Out:
# ['Frase numero 1.', 'Frase número 2.', 'Frase 3.']

# %% [markdown]
# ## -Stemming
#
# * ***Funcionalidad no disponoble en spaCy***

# %% [markdown]
# ## -Lematización
#
#
# * Proceso lingüístico que sustituye una palabra con forma flexionada (plurales, femeninos, verbos conjugados, etc.) por su lema; es decir, por una palabra válida en el idioma.
#
#
# * ***spaCy*** hace una lematización muy buena en Español.
#
#
# * Los objetos de la clase ***Token*** tienen la propiedad (o atributo) ***lemma_*** que nos devuelve el lema del token (o la palabra).

# %%
doc = nlp("Unos radares multan a Mariano Rajoy por ir caminando demasiados rápidos y después el juez lo libera por ser nombrado nueve meses antes por el PP y ahora pertenece a otro partido de derechas")
for word in doc:  
    print(word.text + ' - ' + word.lemma_)
# Out:
# Unos - uno
# radares - radar
# multan - multar
# a - a
# Mariano - Mariano
# Rajoy - Rajoy
# por - por
# ir - ir
# caminando - caminar
# demasiados - demasiado
# rápidos - rápido
# y - y
# después - después
# el - el
# juez - juez
# lo - él
# libera - liberar
# por - por
# ser - ser
# nombrado - nombrar
# nueve - nueve
# meses - mes
# antes - antes
# por - por
# el - el
# PP - PP
# y - y
# ahora - ahora
# pertenece - pertenecer
# a - a
# otro - otro
# partido - partido
# de - de
# derechas - derecha

# %% [markdown]
# ## -Stop words
#
# * Son las palabras que no aportan nada al significado de la frase.
#
#
# * spaCy dispone de más de 500 stop words en Español.
#
#
# * Veamos a continuación las Stop Words en Español.

# %%
stopwords = spacy.lang.es.stop_words.STOP_WORDS
print('Número de stop words: ' + str(len(stopwords)))
print('Stop words: ' + str(list(stopwords)))
# Out:
# Número de stop words: 551
# Stop words: ['encuentra', 'salvo', 'cuántas', 'empleas', 'indicó', 'sera', 'podrá', 'dieron', 'era', 'estamos', 'ninguno', 'tendrá', 'ir', 'próximo', 'usar', 'antes', 'otras', 'hizo', 'explicó', 'nuevos', 'empleo', 'otro', 'modo', 'dónde', 'ti', 'usted', 'dio', 'emplean', 'nuevo', 'tenía', 'debe', 'peor', 'podeis', 'podrán', 'sino', 'ésos', 'según', 'vuestras', 'existe', 'eras', 'poco', 'enseguida', 'ningún', 'dicho', 'intentan', 'paìs', 'sigue', 'teneis', 'mismo', 'quien', 'sido', 'mas', 'tras', 'si', 'consigues', 'supuesto', 'con', 'la', 'quedó', 'trabajamos', 'haciendo', 'dijo', 'misma', 'fuera', 'tu', 'unos', 'incluso', 'allí', 'nuestros', 'podrían', 'pues', 'ni', 'tres', 'muchas', 'hacen', 'quiénes', 'tus', 'hacemos', 'cierta', 'podrias', 'algo', 'detras', 'ese', 'habia', 'solas', 'pronto', 'poca', 'estoy', 'poder', 'últimas', 'cómo', 'consiguen', 'estará', 'sabes', 'eramos', 'hecho', 'te', 'aquello', 'otros', 'esas', 'varias', 'intentamos', 'para', 'arriba', 'vuestros', 'buena', 'días', 'esta', 'yo', 'vez', 'antaño', 'mis', 'siete', 'demás', 'ello', 'posible', 'por', 'va', 'nuevas', 'primero', 'último', 'verdad', 'del', 'esto', 'aquéllas', 'ha', 'estuvo', 'usa', 'ahora', 'siendo', 'unas', 'deprisa', 'solamente', 'todavia', 'esos', 'manifestó', 'ejemplo', 'éstas', 'despacio', 'puede', 'ésas', 'delante', 'somos', 'siempre', 'nueva', 'medio', 'dijeron', 'está', 'final', 'bueno', 'sólo', 'tanto', 'veces', 'momento', 'bien', 'los', 'dias', 'éste', 'aún', 'hago', 'cada', 'adelante', 'ya', 'informo', 'ampleamos', 'se', 'mí', 'da', 'no', 'hace', 'nunca', 'través', 'al', 'señaló', 'ocho', 'suyo', 'trata', 'día', 'saben', 'solos', 'demasiado', 'quizas', 'actualmente', 'fue', 'ningunos', 'mio', 'estos', 'tal', 'ciertas', 'segunda', 'sin', 'vosotros', 'cuantas', 'sí', 'dice', 'soyos', 'respecto', 'parece', 'ellos', 'han', 'claro', 'antano', 'hacia', 'podria', 'eso', 'vuestra', 'parte', 'ser', 'estais', 'contra', 'será', 'solo', 'mi', 'soy', 'buenas', 'propio', 'fuimos', 'sus', 'enfrente', 'quién', 'tenemos', 'le', 'ésa', 'quizá', 'qué', 'sois', 'lugar', 'cuenta', 'fueron', 'algún', 'adrede', 'uno', 'tarde', 'mientras', 'últimos', 'vosotras', 'tienen', 'siguiente', 'cuando', 'haber', 'vaya', 'cuanta', 'nuestra', 'quizás', 'habrá', 'temprano', 'cuáles', 'cuándo', 'llegó', 'lejos', 'menudo', 'tuyo', 'todavía', 'partir', 'consideró', 'detrás', 'verdadero', 'ahi', 'podrian', 'luego', 'intentais', 'buen', 'dos', 'cuántos', 'diferentes', 'estados', 'realizado', 'cualquier', 'segundo', 'trabajo', 'hicieron', 'mucho', 'ademas', 'una', 'ésta', 'tiene', 'algunos', 'usais', 'usamos', 'lleva', 'primer', 'mía', 'debajo', 'ése', 'nuestro', 'alguna', 'muy', 'consigo', 'anterior', 'manera', 'repente', 'entonces', 'dentro', 'cuales', 'así', 'estan', 'haceis', 'cierto', 'nuestras', 'aun', 'mismas', 'debido', 'ex', 'nada', 'última', 'segun', 'estas', 'tercera', 'él', 'poner', 'proximo', 'considera', 'tengo', 'todos', 'hasta', 'les', 'sola', 'dado', 'primeros', 'dicen', 'conseguimos', 'expresó', 'vamos', 'todas', 'general', 'aquélla', 'cuatro', 'hacer', 'sabeis', 'eres', 'van', 'alguno', 'entre', 'en', 'intenta', 'conmigo', 'aquél', 'comentó', 'hemos', 'mejor', 'conseguir', 'existen', 'próximos', 'propias', 'ciertos', 'eran', 'realizar', 'dan', 'horas', 'nosotros', 'varios', 'cuanto', 'tener', 'trabajan', 'cuánto', 'toda', 'raras', 'pasado', 'bastante', 'cinco', 'también', 'fin', 'gueno', 'muchos', 'diferente', 'pocas', 'estaban', 'mediante', 'quiere', 'dejó', 'despues', 'cuál', 'ningunas', 'aquellas', 'esa', 'porque', 'aquéllos', 'había', 'bajo', 'tendrán', 'aunque', 'encima', 'mayor', 'primera', 'cosas', 'dia', 'informó', 'empleais', 'trabajar', 'nos', 'todo', 'aquella', 'ella', 'mías', 'ver', 'propia', 'durante', 'tuyos', 'intentas', 'mencionó', 'trabaja', 'saber', 'intentar', 'hubo', 'tenga', 'pesar', 'como', 'fui', 'usan', 'trabajas', 'es', 'junto', 'este', 'vuestro', 'embargo', 'podriais', 'estaba', 'arribaabajo', 'intento', 'podemos', 'sobre', 'i ...

# %% [markdown]
# * Los objetos de la clase ***Token*** tienen la propiedad ***is_stop*** que devuelve en Boolean indicando si el token es o no una stop word; es decir, si el ***Token*** (o palabra) esta dentro de la lista antes mostrada.
#
#
# * Veamos a continuación como obtener las stop words de una frase con spaCy:

# %%
doc = nlp("Un radar multa a Mariano. Rajoy por caminar demasiado rápido y después el juez lo libera por ser nombrado nueve meses antes por el PP y ahora pertenece a otro partido de derechas")
for word in doc:
    if word.is_stop:
        print(word)
# Out:
# Un
# por
# demasiado
# después
# el
# lo
# por
# ser
# antes
# por
# el
# ahora
# otro
# de

# %% [markdown]
# ## -Part of Speech (PoS)
#
# * En ***spaCy*** el PoS lo divide en 3 tipos de tags que son:
#     1. **pos**: etiqueta simple de alto nivel (verbo, nombre, adjetivo, etc).
#     2. **tag**: etiqueta con más nivel de detalle que el pos.
#     3. **dep**: dependencia sintáctica para ver la relación entre tokens.
#
#
# * Estos 3 tipos son propiedades de la clase ***Token***:

# %%
doc = nlp("Un radar multa a Mariano Rajoy con 300€ por caminar demasiado rápido y después el juez lo libera por ser nombrado nueve meses antes por el PP y ahora pertenece a otro partido de derechas")
pos = [[tk.text, tk.pos_, tk.tag_, tk.dep_] for tk in doc]

import pandas as pd
pd.DataFrame(pos, columns=["Text", "PoS", "TAG", "DEP"])
# Out:
#          Text    PoS    TAG     DEP
# 0          Un    DET    DET     det
# 1       radar   NOUN   NOUN    ROOT
# 2       multa    ADJ    ADJ    amod
# 3           a    ADP    ADP    case
# 4     Mariano  PROPN  PROPN    nmod
# 5       Rajoy  PROPN  PROPN    flat
# 6         con    ADP    ADP    case
# 7         300    NUM    NUM  nummod
# 8           €   NOUN   NOUN    nmod
# 9         por    ADP    ADP    mark
# 10    caminar   VERB   VERB     acl
# 11  demasiado    ADV    ADV  advmod
# 12     rápido    ADJ    ADJ     obj
# 13          y  CCONJ  CCONJ      cc
# 14    después    ADV    ADV  advmod
# 15         el    DET    DET     det
# 16       juez   NOUN   NOUN   nsubj
# 17         lo   PRON   PRON     obj
# 18     libera   VERB   VERB    conj
# 19        por    ADP    ADP    mark
# 20        ser    AUX    AUX     aux
# 21   nombrado   VERB   VERB   advcl
# 22      nueve    NUM    NUM  nummod
# 23      meses   NOUN   NOUN     obl
# 24      antes    ADV    ADV  advmod
# 25        por    ADP    ADP    case
# 26         el    DET    DET     det
# 27         PP  PROPN  PROPN     obj
# 28          y  CCONJ  CCONJ      cc
# 29      ahora    ADV    ADV  advmod
# 30  pertenece   VERB   VERB    conj
# 31          a    ADP    ADP    case
# 32       otro    DET    DET     det
# 33    partido   NOUN   NOUN     obj
# 34         de    ADP    ADP    case
# 35   derechas   NOUN   NOUN    nmod

# %% [markdown]
# ## -Named Entity Recognition (NER)
#
# * Named Entity Recognition (Reconocimiento de Entidades Nombradas) es una tarea de extracción de información que busca localizar y clasificar en categorías predefinidas, como personas, organizaciones, lugares, expresiones de tiempo y cantidades, las entidades nombradas encontradas en un texto.

# %%
doc = nlp("Leo Messi jugador del FC Barcelona marco 34 goles en La Liga 2017-18 en el torneo de 2018-19 esperemos que le vaya mejor y que pueda ser el pichichi del torneo nuevamente llevandose el balón de oro")
for entity in doc.ents:  
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# Leo Messi - PER - Named person or family.
# FC Barcelona - ORG - Companies, agencies, institutions, etc.
# La Liga 2017-18 - MISC - Miscellaneous entities, e.g. events, nationalities, products or works of art

# %% [markdown]
# <hr>
#
#
# # -Resumen
#
# * Una vez creado el documento a partir del texto plano, tenemos ese texto tokenizado.
#
#
# * Los objetos de la clase ***Token*** tienen una serie de propiedades que permiten obtener mucha información relativa a los tokens (o palabras).
#
#
# * Haciendo un resumen de lo visto anteriormente podemos obtener la siguiente información de las palabras de un texto:

# %%
import spacy
import pandas as pd

nlp = spacy.load('es_core_news_sm')
doc = nlp("Un radar multa a Mariano Rajoy con 300€ por caminar demasiado rápido y después el juez lo libera por ser nombrado nueve meses antes por el PP y ahora pertenece a otro partido de derechas")

result = [[tk.text, tk.lemma_, tk.pos_, tk.tag_, tk.dep_, tk.shape_, tk.is_alpha, tk.is_stop] for tk in doc]
pd.DataFrame(result, columns=["Text", "Lema", "PoS", "TAG", "DEP", "Shape", "Alpha", "is Stop word"])
# Out:
#          Text        Lema    PoS    TAG     DEP  Shape  Alpha  is Stop word
# 0          Un         uno    DET    DET     det     Xx   True          True
# 1       radar       radar   NOUN   NOUN    ROOT   xxxx   True         False
# 2       multa       multa    ADJ    ADJ    amod   xxxx   True         False
# 3           a           a    ADP    ADP    case      x   True         False
# 4     Mariano     Mariano  PROPN  PROPN    nmod  Xxxxx   True         False
# 5       Rajoy       Rajoy  PROPN  PROPN    flat  Xxxxx   True         False
# 6         con         con    ADP    ADP    case    xxx   True          True
# 7         300         300    NUM    NUM  nummod    ddd  False         False
# 8           €           €   NOUN   NOUN    nmod      €  False         False
# 9         por         por    ADP    ADP    mark    xxx   True          True
# 10    caminar     caminar   VERB   VERB     acl   xxxx   True         False
# 11  demasiado   demasiado    ADV    ADV  advmod   xxxx   True          True
# 12     rápido      rápido    ADJ    ADJ     obj   xxxx   True         False
# 13          y           y  CCONJ  CCONJ      cc      x   True         False
# 14    después     después    ADV    ADV  advmod   xxxx   True          True
# 15         el          el    DET    DET     det     xx   True          True
# 16       juez        juez   NOUN   NOUN   nsubj   xxxx   True         False
# 17         lo          él   PRON   PRON     obj     xx   True          True
# 18     libera     liberar   VERB   VERB    conj   xxxx   True         False
# 19        por         por    ADP    ADP    mark    xxx   True          True
# 20        ser         ser    AUX    AUX     aux    xxx   True          True
# 21   nombrado     nombrar   VERB   VERB   advcl   xxxx   True         False
# 22      nueve       nueve    NUM    NUM  nummod   xxxx   True         False
# 23      meses         mes   NOUN   NOUN     obl   xxxx   True         False
# 24      antes       antes    ADV    ADV  advmod   xxxx   True          True
# 25        por         por    ADP    ADP    case    xxx   True          True
# 26         el          el    DET    DET     det     xx   True          True
# 27         PP          PP  PROPN  PROPN     obj     XX   True         False
# 28          y           y  CCONJ  CCONJ      cc      x   True         False
# 29      ahora       ahora    ADV    ADV  advmod   xxxx   True          True
# 30  pertenece  pertenecer   VERB   VERB    conj   xxxx   True         False
# 31          a           a    ADP    ADP    case      x   True         False
# 32       otro        otro    DET    DET     det   xxxx   True          True
# 33    partido     partido   NOUN   NOUN     obj   xxxx   True         False
# 34         de          de    ADP    ADP    case     xx   True          True
# 35   derechas     derecha   NOUN   NOUN    nmod   xxxx   True         False

# %% [markdown]
# #### Para más información visitar el siguiente enlace: https://spacy.io/usage/spacy-101#annotations
